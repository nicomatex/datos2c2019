# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mu, sigma = 0,1

# %%
pts_x = np.random.normal(mu,sigma,250)
pts_y = np.random.normal(mu,sigma,250)
plt.plot(pts_x,pts_y,'rx')
plt.axis([-3,3,-3,3])
# Out:
# [-3, 3, -3, 3]

# %% [markdown]
# # SVD Image Decomposition / Compression

# %% [markdown]
# En este notebook exploramos como podemos utilizar la SVD para realizar la compression de una imagen y ir viendo que a medida que realizamos la reduccion de dimensiones vamos perdiendo informacion y como esto afecta a la misma.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import time

from PIL import Image

# %% [markdown]
# ## Preparando el set de datos

# %%
# obtenemos la imagen para poder trabajarla
img = Image.open('andromeda.jpg')
imggray = img.convert('LA')
plt.figure(figsize=(9, 6))
plt.imshow(imggray);

# %%
# llevamos la imagen a una representacion matricial con numpy 
# para poder operar
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat)
# realizamos el plot a partir de la matriz (no la imagen)
plt.figure(figsize=(9,6))
plt.imshow(imgmat, cmap='gray');

# %% [markdown]
# ## SVD

# %%
imgmat
# Out:
# matrix([[48., 24., 25., ..., 15.,  0.,  0.],
#         [27., 29., 26., ..., 22., 17.,  3.],
#         [55., 93., 37., ..., 19., 21., 55.],
#         ...,
#         [25., 20., 23., ..., 45., 62., 43.],
#         [24., 23., 24., ..., 42., 61., 40.],
#         [23., 23., 24., ..., 40., 62., 45.]])

# %%
# realizamos la descomposicion en valores singulares
u, s, v = np.linalg.svd(imgmat)

# %%
# verificamos los valores singulares
s
# Out:
# array([39313.9177176 ,  8484.85259506,  7416.05629503,  3561.31821191,
#         2373.10746665,  2089.76846456,  1743.05365342,  1561.80836014,
#         1494.01575011,  1427.23650548,  1372.61899183,  1348.46349891,
#         1339.94801801,  1318.23851212,  1299.62431403,  1285.05395971,
#         1270.38294786,  1255.1217459 ,  1229.29952348,  1218.60936337,
#         1213.20396412,  1204.42379512,  1174.73771301,  1169.59173457,
#         1165.29618123,  1153.07737483,  1137.56933318,  1128.35770765,
#         1125.38765809,  1121.38604148,  1100.90577846,  1093.75588956,
#         1089.62813403,  1080.55998085,  1069.62471987,  1056.96118657,
#         1054.64263036,  1052.62948212,  1038.39862493,  1033.17020984,
#         1022.96343876,  1016.37889657,  1010.30223251,  1005.79866139,
#          990.39853569,   986.31706744,   978.21634696,   970.03662716,
#          963.63124801,   958.90513075,   957.74527062,   950.663409  ,
#          946.06954589,   938.55114415,   937.59289808,   935.38795667,
#          933.72483955,   912.27808814,   910.47775892,   907.83717568,
#          896.56572139,   890.70746705,   888.7715672 ,   882.01218801,
#          880.33990905,   873.49490546,   870.4434516 ,   861.83006058,
#          855.47573116,   845.52516273,   842.88810692,   837.39300991,
#          834.87828893,   828.53357851,   824.10102518,   821.51318312,
#          817.18315032,   816.12515894,   806.34091128,   804.22721572,
#          799.06461957,   797.61570022,   796.43326205,   791.51820389,
#          783.2294867 ,   782.27457433,   779.00698419,   776.77468691,
#          128.28154709,   127.64388466,   126.36958526,   126.03257234,
#          124.91755194,   124.69965938,   123.72729658,   122.4588664 ,
#          121.07710312,   119.71814723,   119.26069051,   118.53219565,
#          118.2146503 ,   116.49671536,   116.09891438,   115.43814604,
#          113.3954194 ,   112.78696249,   111.40615311,   110.40726395,
#          110.24320423,   109.48488754,   108.57214197,   108.31117359,
#          106.86016323,   106.44826028,   106.0520209 ,   105.75196578,
#          104.24552443,   103.32320571,   102.51489064,   101.03964051,
#          100.08490043,    99.16933542,    98.81011844,    97.48616969,
#           96.91747184,    96.41209464,    95.52016472,    94.89259344,
#           94.44542294,    93.16814117,    92.28744194,    91.55910194,
#           90.4307682 ,    89.51228444,    88.58270019,    88.06312877,
#           87.28871374,    86.72165518,    85.75321118,    85.2889513 ,
#           84.5653502 ,    84.16966464,    83.9424062 ,    82.65299484,
#           81.37841506,    80.89814387,    80.37146864,    79.42454586,
#           78.23051069,    78.09925124,    77.28271616,    76.39618235,
#           75.60513636,    73.89199128,    72.82237662,    71.51341614,
#           71.00592457,    70.62411372,    69.62210985,    69.21102727,
#           68.461049  ,    68.00512247,    67.39128887,    66.36140714,
#           64.55504481,    63.10548373,    62.48227612,    60.82293162,
#           59.68479022,    58.59610207,    58.39528146,    57.58864936,
#           56.58504967,    55.99803629,    55.35092168,    54.37742342,
#           53.90745989,    50.67682283,    49.93551838,    49.22865423,
#           47.6108386 ])

# %% [markdown]
# ## Analisis de valores singulares

# %%
# realizamos un plot de los valores singulaes
# es interesante ir reduciendo el rango para poder 
# verificar algun posible 'codo' para poder considerar 
# la dimensionalidad intrinseca de los datos
#plt.plot(s)
plt.plot(s[:10])

# %% [markdown]
# ## Reconstruyendo la imagen a partir de los datos reducidos

# %%
u[:,:2]
# Out:
# matrix([[-0.0135571 ,  0.00731296],
#         [-0.01458063,  0.00700102],
#         [-0.014239  ,  0.00924376],
#         ...,
#         [-0.01413324,  0.00187751],
#         [-0.01369515, -0.00013969],
#         [-0.01327389,  0.00164602]])

# %%
reconstimg = np.matrix(u[:, :55]) * np.diag(s[:55]) * np.matrix(v[:55, :])
plt.figure(figsize=(9,6))
plt.imshow(reconstimg, cmap='gray');

# %%
for i in range(2, 4):
    reconstimg = np.matrix(u[:, :i]) * np.diag(s[:i]) * np.matrix(v[:i, :])
    plt.figure(figsize=(9,6))
    plt.imshow(reconstimg, cmap='gray')
    title = "k = %s" % i
    plt.title(title)
    plt.show()

# %%
for i in range(5, 51, 5):
    reconstimg = np.matrix(u[:, :i]) * np.diag(s[:i]) * np.matrix(v[:i, :])
    plt.figure(figsize=(9,6))
    plt.imshow(reconstimg, cmap='gray')
    title = "k = %s" % i
    plt.title(title)
    plt.show()
